# %% [markdown]
# # 03__CRISPhieRmix
#
# in this notebook, i run CRISPhieRmix on the filtered sgRNA log2 fold changes

# %%
#install.packages("devtools")

# %%
#devtools::install_github("timydaley/CRISPhieRmix")

# %%
library(CRISPhieRmix)

# %% [markdown]
# ## 1. import data, get variables needed

# %%
data_f = "../../../data/02__screen/02__enrichment_data/data_filt.tmp"

# %%
data <- read.table(data_f, sep="\t", header=TRUE)
head(data)
# Out:
#   sgRNA                ctrl_status  gene_id             gene_name
# 1 GGGAAGTGAGATGACGGTCG experimental ENSG00000224616.1_1 RTCA-AS1
# 2 GGAAGTGAGATGACGGTCGC experimental ENSG00000224616.1_1 RTCA-AS1
# 3 GAAGTGAGATGACGGTCGCG experimental ENSG00000224616.1_1 RTCA-AS1
# 4 CCCTGAAAAACTTGTGCCCT experimental ENSG00000224616.1_1 RTCA-AS1
# 5 CTGCCGGGGAAGTGAGATGA experimental ENSG00000224616.1_1 RTCA-AS1
# 6 GCCCTGAAAAACTTGTGCCC experimental ENSG00000224616.1_1 RTCA-AS1
#   transcript_id       transcript_name transcript_biotype_status tss_chr_hg38
# 1 ENST00000421185.1_1 RTCA-AS1-001    promoter_overlap          chr1
# 2 ENST00000421185.1_1 RTCA-AS1-001    promoter_overlap          chr1
# 3 ENST00000421185.1_1 RTCA-AS1-001    promoter_overlap          chr1
# 4 ENST00000421185.1_1 RTCA-AS1-001    promoter_overlap          chr1
# 5 ENST00000421185.1_1 RTCA-AS1-001    promoter_overlap          chr1
# 6 ENST00000421185.1_1 RTCA-AS1-001    promoter_overlap          chr1
#   tss_start_hg38 tss_strand_hg38 ... scramble_id group_id
# 1 100266115      -               ... none        NC_000001.11:-:100266115
# 2 100266115      -               ... none        NC_000001.11:-:100266115
# 3 100266115      -               ... none        NC_000001.11:-:100266115
# 4 100266115      -               ... none        NC_000001.11:-:100266115
# 5 100266115      -               ... none        NC_000001.11:-:100266115
# 6 100266115      -               ... none        NC_000001.11:-:100266115
#   baseMean  l2fc       l2fcSE    stat       pvalue    padj      sgRNA_filt
# 1 1671.8090  0.1560526 0.3464962 -0.4503732 0.6524413 0.9753066 8
# 2 2134.0367  0.6238106 0.5644095 -1.1052448 0.2690535 0.7215195 8
# 3 1498.1057  0.5115188 1.2127901 -0.4217702 0.6731927 0.9799771 8
# 4 3266.6648  0.2939041 0.3164348 -0.9287981 0.3529937 0.8110083 8
# 5 1419.4305  0.7606535 0.7315023 -1.0398512 0.2984090 0.7547979 8
# 6  687.5139 -0.2987762 0.6407559  0.4662871 0.6410100 0.9717101 8
#   group_id_rd
# 1 RTCA-AS1-001;;;NC_000001.11:-:100266115;;;experimental;;;promoter_overlap;;;8
# 2 RTCA-AS1-001;;;NC_000001.11:-:100266115;;;experimental;;;promoter_overlap;;;8
# 3 RTCA-AS1-001;;;NC_000001.11:-:100266115;;;experimental;;;promoter_overlap;;;8
# 4 RTCA-AS1-001;;;NC_000001.11:-:100266115;;;experimental;;;promoter_overlap;;;8
# 5 RTCA-AS1-001;;;NC_000001.11:-:100266115;;;experimental;;;promoter_overlap;;;8
# 6 RTCA-AS1-001;;;NC_000001.11:-:100266115;;;experimental;;;promoter_overlap;;;8

# %%
names(data)
# Out:
#  [1] "sgRNA"                     "ctrl_status"
#  [3] "gene_id"                   "gene_name"
#  [5] "transcript_id"             "transcript_name"
#  [7] "transcript_biotype_status" "tss_chr_hg38"
#  [9] "tss_start_hg38"            "tss_strand_hg38"
# [11] "tss_type"                  "tss_id_hg38"
# [13] "sgRNA_id"                  "DZ_Rep1__counts"
# [15] "DZ_Rep2__counts"           "Pos_Rep1__counts"
# [17] "Pos_Rep2__counts"          "Neg_Rep1__counts"
# [19] "Neg_Rep2__counts"          "DZ_Rep1__cpm"
# [21] "DZ_Rep2__cpm"              "Pos_Rep1__cpm"
# [23] "Pos_Rep2__cpm"             "Neg_Rep1__cpm"
# [25] "Neg_Rep2__cpm"             "scramble_id"
# [27] "group_id"                  "baseMean"
# [29] "l2fc"                      "l2fcSE"
# [31] "stat"                      "pvalue"
# [33] "padj"                      "sgRNA_filt"
# [35] "group_id_rd"

# %%
# x needs to be the l2fcs of target genes
tgts <- data[which(data$ctrl_status != "scramble"), ]
x <- tgts$l2fc
head(x)
# Out:
# [1]  0.1560526  0.6238106  0.5115188  0.2939041  0.7606535 -0.2987762

# %%
# geneIds needs to be the geneIds associated with x
geneIds <- tgts$group_id_rd
head(geneIds)
# Out:
# [1] RTCA-AS1-001;;;NC_000001.11:-:100266115;;;experimental;;;promoter_overlap;;;8
# [2] RTCA-AS1-001;;;NC_000001.11:-:100266115;;;experimental;;;promoter_overlap;;;8
# [3] RTCA-AS1-001;;;NC_000001.11:-:100266115;;;experimental;;;promoter_overlap;;;8
# [4] RTCA-AS1-001;;;NC_000001.11:-:100266115;;;experimental;;;promoter_overlap;;;8
# [5] RTCA-AS1-001;;;NC_000001.11:-:100266115;;;experimental;;;promoter_overlap;;;8
# [6] RTCA-AS1-001;;;NC_000001.11:-:100266115;;;experimental;;;promoter_overlap;;;8
# 9772 Levels:  ...

# %%
# negCtrl needs to be the l2fcs of scrambles
negs <- data[which(data$ctrl_statu == "scramble"), ]
negCtrl <- negs$l2fc
head(negCtrl)
# Out:
# [1]  2.0314318 -0.2172307  0.1108344  1.1284910 -0.5291742 -0.4968356

# %%
l2fc.CRISPhieRmix <- CRISPhieRmix(x = x, geneIds = geneIds, negCtrl = negCtrl,
                                  VERBOSE = TRUE, PLOT = TRUE)
# Out:
# fit negative control distributions
# 2 groups
# converged
# mu =  2.166319
# sigma =  2.124233
# pq =  0.005050151
# Plot with title “negative control fit”
# Plot with title “mixture fit to observations”

# %%
hist(l2fc.CRISPhieRmix$FDR, breaks = 100)
# Out:
# Plot with title “Histogram of l2fc.CRISPhieRmix$FDR”

# %%
sum(l2fc.CRISPhieRmix$FDR < 0.1)
# Out:
# [1] 78

# %%
sum(l2fc.CRISPhieRmix$FDR < 0.05)
# Out:
# [1] 67

# %%
scores <- data.frame(groups = l2fc.CRISPhieRmix$genes, FDR = l2fc.CRISPhieRmix$FDR)
head(scores[order(scores$FDR, decreasing = FALSE), ], 80)
# Out:
#      groups
# 677  [RP11-120D5.1-004, RP11-120D5.1-005];;;NC_000023.11:-:11111137;;;experimental;;;promoter_overlap;;;7
# 3278 EOMES-001;;;NC_000003.12:-:27722322;;;control;;;protein_coding;;;6
# 3279 EOMES-004;;;NC_000003.12:-:27722707;;;control;;;protein_coding;;;6
# 9415 SOX17-001;;;NC_000008.11:+:54457934;;;control;;;protein_coding;;;7
# 1912 ACVR2B-AS1-001;;;NC_000003.12:-:38454682;;;experimental;;;promoter_overlap;;;10
# 5205 RP11-121L10.2-001;;;NC_000011.10:+:90223166;;;experimental;;;promoter_overlap;;;8
#      FDR
# 677  0.000000e+00
# 3278 0.000000e+00
# 3279 0.000000e+00
# 9415 0.000000e+00
# 1912 1.265654e-15
# 5205 4.033810e-15
# 9359 9.154550e-12
# 3378 4.842431e-11
# 8979 3.120178e-10
# 9465 8.773907e-10
# 3554 1.341127e-09
# 82   1.770453e-09
# 9020 2.477936e-09
# 3005 3.361643e-09
# 670  4.389408e-09
# 6828 6.190223e-09
# 4506 9.275573e-09
# 6306 7.756411e-08
# 5289 1.603717e-07
# 250  2.446678e-07
# 5232 3.416391e-07
# 7514 6.114064e-07
# 911  1.051599e-06
# 4644 2.158127e-06
# 941  3.356508e-06
# 1488 4.481770e-06
# 4659 5.694790e-06
# 3607 6.925607e-06
# 3404 9.068633e-06
# 3877 1.108794e-05
# ...  ...
# 3464 0.003621300
# 3076 0.004653946
# 9122 0.005662010
# 3387 0.007373717
# 2662 0.009049607
# 9647 0.011129019
# 375  0.013301846
# 1000 0.016237049
# 4492 0.019075663
# 3383 0.021871721
# 4490 0.025024938
# 1583 0.028220809
# 4891 0.031464084
# 1908 0.034885080
# 7758 0.038915921
# 6813 0.042828114
# 5144 0.046915042
# 5666 0.050886065
# 7991 0.054793013
# 4815 0.058643957
# 5664 0.062628937
# 801  0.066968765
# 4390 0.071513172
# 3212 0.076334196
# 5055 0.081830050
# 2880 0.087370442
# 1830 0.093247390
# 7746 0.099080018
# 1001 0.104779877
# 1153 0.110400695

# %%
sig <- scores[which(scores$FDR < 0.1), ]
nrow(sig)
# Out:
# [1] 78

# %%
sig[grep("control", sig$groups), ]
# Out:
#      groups
# 3278 EOMES-001;;;NC_000003.12:-:27722322;;;control;;;protein_coding;;;6
# 3279 EOMES-004;;;NC_000003.12:-:27722707;;;control;;;protein_coding;;;6
# 3378 FOXA2-002;;;NC_000020.11:-:22584571;;;control;;;protein_coding;;;9
# 3416 GATA6-001;;;NC_000018.10:+:22169434;;;control;;;protein_coding;;;7
# 3464 GSC-001;;;NC_000014.9:-:94770237;;;control;;;protein_coding;;;3
# 9415 SOX17-001;;;NC_000008.11:+:54457934;;;control;;;protein_coding;;;7
#      FDR
# 3278 0.000000e+00
# 3279 0.000000e+00
# 3378 4.842431e-11
# 3416 6.757129e-05
# 3464 3.621300e-03
# 9415 0.000000e+00

# %%
scores[grep("DIGIT|FOXA2|SOX17", scores$groups), ]
# Out:
#      groups
# 3212 DIGIT;;;NC_000014.9:+:94770641;;;experimental;;;promoter_overlap;;;4
# 3378 FOXA2-002;;;NC_000020.11:-:22584571;;;control;;;protein_coding;;;9
# 9415 SOX17-001;;;NC_000008.11:+:54457934;;;control;;;protein_coding;;;7
#      FDR
# 3212 7.633420e-02
# 3378 4.842431e-11
# 9415 0.000000e+00

# %%
nrow(scores)
# Out:
# [1] 9771

# %%
write.table(scores, file = "../../../data/02__screen/02__enrichment_data/CRISPhieRmix.txt", quote = FALSE, 
            sep = "\t", row.names = FALSE)
